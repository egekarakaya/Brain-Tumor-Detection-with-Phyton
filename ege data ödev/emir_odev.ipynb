# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np #for linear algebra
import pandas as pd #for reading csv files and data processing
import matplotlib.pyplot as plt #for plotting
import seaborn as sns #for heatmap

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading Data

# %%
data = pd.read_csv('data.csv') #data file input

# %% [markdown]
# ## A)

# %%
count_of_features = len(data.columns)
count_of_features #the file has 33 features (columns)
# Out:
# 33

# %% [markdown]
# ## B)

# %%
data.info() #with .info ,we can say that the file has 569 entries , the data types are int64 ,object and float and the memory usage is 146.8 Kb.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %% [markdown]
# # C)

# %%
data.describe() # to find the statistical properties of features
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
#from .info we can realise that 32th columns all values are NaN values and we can get rid of the problem by deleting the 

data.drop('Unnamed: 32', axis=1, inplace=True)

# %% [markdown]
# # D)

# %%
data.shape #data shape changes because we deleted one column
# Out:
# (569, 32)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# # F)

# %%
plt.figure(figsize=(20,20)) #it is easier to see the correlation with a heatmap
sns.heatmap(data.corr().round(2), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 2. A)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The logistic regression works as ; The inputs are multiplied with weights and the bias is added as sum ==> sum is inserted in sigmoid function ==> sigmoid function output is a prediction result.

# %% [markdown]
# # B)

# %%
from sklearn.svm import SVC 

y =data["diagnosis"].values
x_data = data.drop(["diagnosis"],axis=1)

x = (x_data - np.min(x_data))/(np.max(x_data)-np.min(x_data))

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.15,random_state=1)
 
svm =SVC(random_state = 1)
svm.fit(x_train,y_train)


print("Support Vector Machine Model Test Accuracy: {} ".format(svm.score(x_test,y_test)))
# Out:
# Support Vector Machine Model Test Accuracy: 0.9534883720930233

# %%
sns.scatterplot(x='compactness_mean', y='area_mean', hue='diagnosis', data=data)
plt.title('compactness mean and area mean distribution') #I chose compactness mean and area mean distribution
plt.show()

# %% [markdown]
# # 3)

# %% [markdown]
# I chose knn , decision tree and random forest.

# %% [markdown]
# # KNN

# %%
y = data["diagnosis"].values
x_data = data.drop(["diagnosis"],axis=1)

x = (x_data - np.min(x_data))/(np.max(x_data)-np.min(x_data))

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.15,random_state=1)

from sklearn.neighbors import KNeighborsClassifier
komsu_sayisi = 9
knn = KNeighborsClassifier(n_neighbors = komsu_sayisi) 
knn.fit(x_train,y_train)

prediction = knn.predict(x_test)
print(" {} Nearest Neighbor Model Test Accuracy: {} ".format(komsu_sayisi,knn.score(x_test,y_test)))
# Out:
#  9 Nearest Neighbor Model Test Accuracy: 0.9418604651162791

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
model2 = dtc.fit(x_train,y_train)
prediction2 = model2.predict(x_test)
accuracy_score(y_test,prediction2)
# Out:
# 0.9418604651162791

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier()
model3 = rfc.fit(x_train, y_train)
prediction3 = model3.predict(x_test)
accuracy_score(y_test,prediction3)
# Out:
# 0.9302325581395349
